# %%
# First we need to mount the Google drive 
import os
from google.colab import drive
drive.mount('/content/gdrive')
# Here specify the path to your directory
# !ls "/content/gdrive/My Drive/ResNet_CIFAR10_TF" 
root_path = 'gdrive/My Drive/ResNet_CIFAR10_TF' 
path = '/content/gdrive/My Drive/ResNet_CIFAR10_TF'
os.chdir(path)
# Out:
# Mounted at /content/gdrive
# ResNext29_2x64de100.png  saved_models
# ResNext29_2x64d.png	 tf_resnext_cifar10.ipynb

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import tensorflow as tf
from tensorflow.keras import initializers
from tensorflow.keras.layers import Lambda
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.layers import Dense, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, MaxPool2D, Input
from tensorflow.keras.layers import Flatten, add
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import to_categorical
import numpy as np
import os
import math
import csv
import tensorflow.keras.backend as K
from tensorflow import keras
import pandas as pd
import matplotlib.pyplot as plt

# training parameters
batch_size = 128 # 32 # orig paper trained all networks with batch_size=128
weight_decay = 0.0005
momentum = 0.9
learning_rate = 0.1
reducing_lr = 0.1
epochs = 300
data_augmentation = True
num_classes = 10

# network settings
depth = 29
cardinality = 8 # 2
width = 64

# subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# model name, depth and version
model_type = 'ResNext%d_%dx%dd' % (depth, cardinality, width)
print("Model type: ", model_type)

# load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# input image dimensions.
input_shape = x_train.shape[1:]

# normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# if subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# convert class vectors to binary class matrices.
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)


def lr_schedule(epoch):
    """Learning Rate Schedule
    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.
    # Arguments
        epoch (int): The number of epochs
    # Returns
        lr (float32): learning rate
    """
    # lr = 1e-3
    lr = learning_rate
    # if epoch > 180:
    #     lr *= 0.5e-3
    # elif epoch > 160:
    #     lr *= 1e-3
    # elif epoch > 120:
    #     lr *= 1e-2
    # elif epoch > 80:
    #     lr *= 1e-1
    if epoch == 150:
      lr *= reducing_lr
    elif epoch == 225:
      lf *= reducing_lr
    print('Learning rate: ', lr)
    return lr
# Out:
# Model type:  ResNext29_8x64d
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
def resnet_layer(inputs,
                 num_filters=64,
                 kernel_size=3,
                 strides=1,
                 groups=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder
    Arguments:
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        groups (int): the number of groups (cardinality)
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)
    Returns:
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  groups=groups,
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(weight_decay)) # 1e-4 

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


# def pad_depth(x, desired_channels):
#     y = K.zeros_like(x, name='pad_depth1')
#     new_channels = desired_channels - x.shape.as_list()[-1]
#     print('desired_channels:', desired_channels)
#     print('new_channels:', new_channels)
#     y = y[:, :, :new_channels]
#     return K.concatenate([x, y])


def pad_depth(x, desired_channels):
    new_channels = desired_channels - x.shape.as_list()[-1]
    output = tf.identity(x)
    repetitions = new_channels / x.shape.as_list()[-1]
    for _ in range(int(repetitions)):
        zeroTensors = tf.zeros_like(x, name='pad_depth1')
        output = tf.keras.backend.concatenate([output, zeroTensors])
    return output


def resnext29(input_shape, channels, groups, width_per_group, shortcut='A'): # 2x64d (groups: 2, width_per_group: 64)
    expansion = 4
    # num_filters = 64
    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # num_filters = groups * width_per_group

    for stage in range(3):
        depth = int(math.floor(channels * (width_per_group / 64.0)))
        for res_block in range(3):
            strides = 1
            # first layer but not first stage
            if stage > 0 and res_block == 0:  
                strides = 2  # downsample
            # Conv 1x1, BN, ReLU
            y = resnet_layer(inputs=x,
                             num_filters=depth * groups, # num_filters
                             kernel_size=1,
                             strides=strides,
                             groups=1) # groups=groups
            # Conv 3x3, BN, ReLU
            y = resnet_layer(inputs=y,
                             num_filters=depth * groups, # num_filters
                             kernel_size=3,
                             groups=groups)
            # Conv 1x1, BN
            y = resnet_layer(inputs=y,
                             num_filters=channels * 4, # * 2 -> num_filters * expansion
                             kernel_size=1,
                             groups=1, # groups=groups
                             activation=None,
                             batch_normalization=True)
            # downsampling for shortcut
            if res_block == 0:
                if shortcut == 'A':
                    x = MaxPool2D(pool_size=(1, 1), strides=(strides, strides), padding='same')(x)
                    x = Lambda(pad_depth, arguments={'desired_channels': channels * expansion})(x)
                elif shortcut == 'B':
                    # linear projection residual shortcut
                    # connection to match changed dims
                    x = resnet_layer(inputs=x,
                                    num_filters=channels * 4, # * 2 -> num_filters * expansion
                                    kernel_size=1,
                                    groups=1, # groups=groups
                                    strides=strides,
                                    activation=None,
                                    batch_normalization=True)
                # if stage > 0:
                #     strides = 2

                # x = Lambda(pad_depth, name='identity_shortcut', arguments={'desired_channels': channels * 2})(x)
                # identity_weights = np.eye(channels, channels * expansion, dtype=np.float32)
                # layer = Conv2D(channels * expansion, kernel_size=1, strides=strides, use_bias=False, 
                #                kernel_initializer=initializers.Constant(value=identity_weights))
                # layer.trainable = False
                # x = layer(x)

            x = add([x, y])
            x = Activation('relu')(x)
        # num_filters *= 2
        channels *= 2

    # add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# ### Another Code for ResNext

# %%
from tensorflow.keras.layers import Conv2D, Dense, ReLU, GlobalAveragePooling2D, BatchNormalization, Add, Flatten, Input, Softmax, ZeroPadding2D, AveragePooling2D
from tensorflow.keras import Model
from tensorflow.keras.initializers import VarianceScaling, HeNormal
from tensorflow.keras.regularizers import L2
import tensorflow as tf
import numpy as np

weight_init = VarianceScaling()
weight_regularizer = L2(0.0001)

He_init = HeNormal(seed=123)

def ResNextBlock(inputs, ch, d, cardinality, stride=1, use_bias=True):
    bottleneck_width = d * cardinality
    out_channel = ch * 4
   
    Conv_1 = Conv2D(bottleneck_width, 1, 1, use_bias=use_bias, kernel_initializer=He_init, kernel_regularizer=weight_regularizer)(inputs)
    BN_1 = BatchNormalization(momentum=0.9, epsilon=1e-5)(Conv_1)
    ReLu_1 = ReLU()(BN_1)
   
    Conv_2 = Conv2D(bottleneck_width, 3, strides=stride, use_bias=use_bias, padding='same', groups=cardinality, kernel_initializer=He_init, kernel_regularizer=weight_regularizer)(ReLu_1)
    BN_2 = BatchNormalization(momentum=0.9, epsilon=1e-5)(Conv_2)
    ReLu_2 = ReLU()(BN_2)
   
    Conv_3 = Conv2D(out_channel, 1, 1, use_bias=use_bias, kernel_initializer=He_init, kernel_regularizer=weight_regularizer)(ReLu_2)
    BN_3 = BatchNormalization(momentum=0.9, epsilon=1e-5)(Conv_3)

    
    if stride != 1:
        inputs = inputs[:,::2,::2,:]
#         inputs = tf.pad(inputs, [[0,0], [0,0], [0,0], [0, bottleneck_width]], "CONSTANT", name="zeroPadding")
       
    if BN_3.shape[3] != inputs.shape[3]:
        inputs = tf.pad(inputs, [[0,0], [0,0], [0,0], [0,BN_3.shape[3]-inputs.shape[3]]], "CONSTANT", name="zeroPadding")
       
    Shortcut = Add()([BN_3, inputs])
    ReLu_3 = ReLU()(Shortcut)
    return ReLu_3

def ResNeXt(shape=(32,32,3), n = 3, d=64, cardinality=1, use_bias=True):
    inputs = Input(shape=shape)
    ch = 64
   
    Conv_1 = Conv2D(ch, 3, 1, use_bias=use_bias, padding='same', kernel_initializer=He_init, kernel_regularizer=weight_regularizer)(inputs)
    BN_1 = BatchNormalization(momentum=0.9, epsilon=1e-5)(Conv_1)
    ReLU_1 = ReLU()(BN_1)
   
    ResNext_1 = ReLU_1
    for i in range(n):
        ResNext_1 = ResNextBlock(ResNext_1, ch, d, cardinality, use_bias=use_bias)
       
    ResNext_2 = ResNextBlock(ResNext_1, ch*2, d*2, cardinality, 2, use_bias=use_bias)
    for i in range(1,n):
        ResNext_2 = ResNextBlock(ResNext_2, ch*2, d*2, cardinality, use_bias=use_bias)
       
    ResNext_3 = ResNextBlock(ResNext_2, ch*4, d*4, cardinality, 2, use_bias=use_bias)
    for i in range(1,n):
        ResNext_3 = ResNextBlock(ResNext_3, ch*4, d*4, cardinality, use_bias=use_bias)
   
    GAP = GlobalAveragePooling2D()(ResNext_3)
    flatten = Flatten()(GAP)
    dense = Dense(10, activation='softmax', kernel_initializer=He_init, kernel_regularizer=weight_regularizer)(flatten)
   
    return Model(inputs=inputs, outputs=dense, name="ResNext{}({}x{}d)".format(9*n+2, cardinality, d))

# %% [markdown]
# ### Parameters comparison

# %%
model = ResNeXt(cardinality=8)
model.summary()
plot_model(model, show_shapes=True)
# Out:
# Model: "ResNext29(8x64d)"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   1792        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 32, 32, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 512)  33280       re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 512)  2048        conv2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 32, 32, 512)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 512)  295424      re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 512)  2048        conv2d_2[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 32, 32, 512)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 256)  131328      re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 256)  1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.pad (TFOpLambda)   (None, 32, 32, 256)  0           re_lu[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 256)  0           batch_normalization_3[0][0]
#                                                                  tf.compat.v1.pad[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 32, 32, 256)  0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 512)  131584      re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 512)  2048        conv2d_4[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 32, 32, 512)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 512)  295424      re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 512)  2048        conv2d_5[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 32, 32, 512)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 256)  131328      re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 256)  0           batch_normalization_6[0][0]
#                                                                  re_lu_3[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 32, 32, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  131584      re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 32, 32, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 512)  295424      re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 512)  2048        conv2d_8[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 32, 32, 512)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 256)  131328      re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 256)  1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 256)  0           batch_normalization_9[0][0]
#                                                                  re_lu_6[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 32, 32, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 1024) 263168      re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 1024) 4096        conv2d_10[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 32, 32, 1024) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 1024) 1180672     re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 1024) 4096        conv2d_11[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 16, 16, 1024) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 512)  524800      re_lu_11[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 16, 16, 256)  0           re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 512)  2048        conv2d_12[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.pad_1 (TFOpLambda) (None, 16, 16, 512)  0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 512)  0           batch_normalization_12[0][0]
#                                                                  tf.compat.v1.pad_1[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 16, 16, 512)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 1024) 525312      re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 1024) 4096        conv2d_13[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 16, 16, 1024) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 1024) 1180672     re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 1024) 4096        conv2d_14[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 16, 16, 1024) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 512)  524800      re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 512)  2048        conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 512)  0           batch_normalization_15[0][0]
#                                                                  re_lu_12[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 16, 16, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 1024) 525312      re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 16, 1024) 4096        conv2d_16[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 16, 16, 1024) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 1024) 1180672     re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 1024) 4096        conv2d_17[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 16, 16, 1024) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 512)  524800      re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 16, 512)  2048        conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 512)  0           batch_normalization_18[0][0]
#                                                                  re_lu_15[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 16, 16, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 2048) 1050624     re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 16, 2048) 8192        conv2d_19[0][0]
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, 16, 16, 2048) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 2048)   4720640     re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 8, 8, 2048)   8192        conv2d_20[0][0]
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, 8, 8, 2048)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 1024)   2098176     re_lu_20[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1 (Sli (None, 8, 8, 512)    0           re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 8, 8, 1024)   4096        conv2d_21[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.pad_2 (TFOpLambda) (None, 8, 8, 1024)   0           tf.__operators__.getitem_1[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 1024)   0           batch_normalization_21[0][0]
#                                                                  tf.compat.v1.pad_2[0][0]
# __________________________________________________________________________________________________
# re_lu_21 (ReLU)                 (None, 8, 8, 1024)   0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 2048)   2099200     re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 8, 8, 2048)   8192        conv2d_22[0][0]
# __________________________________________________________________________________________________
# re_lu_22 (ReLU)                 (None, 8, 8, 2048)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 8, 2048)   4720640     re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 8, 8, 2048)   8192        conv2d_23[0][0]
# __________________________________________________________________________________________________
# re_lu_23 (ReLU)                 (None, 8, 8, 2048)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 8, 1024)   2098176     re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 8, 8, 1024)   4096        conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 1024)   0           batch_normalization_24[0][0]
#                                                                  re_lu_21[0][0]
# __________________________________________________________________________________________________
# re_lu_24 (ReLU)                 (None, 8, 8, 1024)   0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 8, 2048)   2099200     re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 8, 2048)   8192        conv2d_25[0][0]
# __________________________________________________________________________________________________
# re_lu_25 (ReLU)                 (None, 8, 8, 2048)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 8, 8, 2048)   4720640     re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 8, 2048)   8192        conv2d_26[0][0]
# __________________________________________________________________________________________________
# re_lu_26 (ReLU)                 (None, 8, 8, 2048)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 8, 8, 1024)   2098176     re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 8, 1024)   4096        conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 1024)   0           batch_normalization_27[0][0]
#                                                                  re_lu_24[0][0]
# __________________________________________________________________________________________________
# re_lu_27 (ReLU)                 (None, 8, 8, 1024)   0           add_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1024)         0           re_lu_27[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           10250       flatten[0][0]
# ==================================================================================================
# Total params: 33,832,202
# Trainable params: 33,778,314
# Non-trainable params: 53,888
# __________________________________________________________________________________________________

# %%
model = resnext29(input_shape=input_shape, channels=64, groups=cardinality, width_per_group=width)
model.compile(loss='categorical_crossentropy',
              optimizer=SGD(lr=learning_rate, momentum=momentum), # Adam(lr=lr_schedule(0))  
              metrics=['acc'])
model.summary()
plot_model(model, show_shapes=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   1792        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 512)  33280       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 512)  2048        conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 512)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 512)  295424      activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 512)  2048        conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 512)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 256)  131328      activation_2[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 32, 32, 256)  0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 256)  1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 256)  0           lambda[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 256)  0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 512)  131584      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 512)  2048        conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 512)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 512)  295424      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 512)  2048        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 512)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 256)  131328      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 256)  0           activation_3[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  131584      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 512)  295424      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 512)  2048        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 512)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 256)  131328      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 256)  1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 256)  0           activation_6[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 1024) 263168      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 1024) 4096        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 1024) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 1024) 1180672     activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 1024) 4096        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 1024) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 256)  0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 512)  524800      activation_11[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 16, 16, 512)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 512)  2048        conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 512)  0           lambda_1[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 512)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 1024) 525312      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 1024) 4096        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 1024) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 1024) 1180672     activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 1024) 4096        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 1024) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 512)  524800      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 512)  2048        conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 512)  0           activation_12[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 16, 16, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 1024) 525312      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 16, 1024) 4096        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 16, 16, 1024) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 1024) 1180672     activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 1024) 4096        conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 16, 16, 1024) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 512)  524800      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 16, 512)  2048        conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 512)  0           activation_15[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 16, 16, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 2048)   1050624     activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 2048)   8192        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 2048)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 2048)   4720640     activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 8, 8, 2048)   8192        conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 8, 8, 2048)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 512)    0           activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 1024)   2098176     activation_20[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 8, 8, 1024)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 8, 8, 1024)   4096        conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 1024)   0           lambda_2[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 8, 8, 1024)   0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 2048)   2099200     activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 8, 8, 2048)   8192        conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 8, 8, 2048)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 8, 2048)   4720640     activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 8, 8, 2048)   8192        conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 8, 8, 2048)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 8, 1024)   2098176     activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 8, 8, 1024)   4096        conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 1024)   0           activation_21[0][0]
#                                                                  batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 8, 8, 1024)   0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 8, 2048)   2099200     activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 8, 2048)   8192        conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 8, 8, 2048)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 8, 8, 2048)   4720640     activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 8, 2048)   8192        conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 8, 8, 2048)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 8, 8, 1024)   2098176     activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 8, 1024)   4096        conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 1024)   0           activation_24[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 8, 8, 1024)   0           add_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 1024)   0           activation_27[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           10250       flatten[0][0]
# ==================================================================================================
# Total params: 33,832,202
# Trainable params: 33,778,314
# Non-trainable params: 53,888
# __________________________________________________________________________________________________

# %%
# enable this if pydot can be installed
# pip install pydot
plot_model(model, to_file="%s.png" % model_type, show_shapes=True)

# %%
model_name = model_type + f'_e{epochs}'
print('model_name:', model_name)

# prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
print('save_dir: ', save_dir)

# model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
model_save_name = 'cifar10_%s.h5' % model_name
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

model_directory = os.path.join(save_dir, model_name)
print('model_directory:', model_directory)

if not os.path.isdir(model_directory):
    os.makedirs(model_directory)

filepath = os.path.join(model_directory, model_save_name)
print('filepath:', filepath)

# prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(monitor='val_acc',
                               factor=0.1, # np.sqrt(0.1)
                               patience=5, # 10
                               verbose=1,
                               mode='max',
                               cooldown=0,
                               min_lr=0.5e-6)
# Out:
# model_name: ResNext29_2x64d_e300
# save_dir:  /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models
# model_directory: /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300
# filepath: /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300/cifar10_ResNext29_2x64d_e300.h5

# %%
class StoreModelHistory(keras.callbacks.Callback):

  def on_epoch_end(self, batch, logs=None):
    if ('lr' not in logs.keys()):
      logs.setdefault('lr', 0)
      logs['lr'] = K.get_value(self.model.optimizer.lr)

    if not ('model_history.csv' in os.listdir(model_directory)):
      with open(model_directory + '/model_history.csv', 'a') as f:
        y = csv.DictWriter(f, logs.keys())
        y.writeheader()

    with open(model_directory + '/model_history.csv', 'a') as f:
      y = csv.DictWriter(f, logs.keys())
      y.writerow(logs)

# %%
callbacks = [StoreModelHistory(), checkpoint, lr_scheduler] # , lr_reducer

# %%
# run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # this will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False)

    # compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    steps_per_epoch =  math.ceil(len(x_train) / batch_size)
    # fit the model on the batches generated by datagen.flow().
    model.fit(x=datagen.flow(x_train, y_train, batch_size=batch_size),
              verbose=1,
              epochs=epochs,
              validation_data=(x_test, y_test),
              steps_per_epoch=steps_per_epoch,
              callbacks=callbacks)


# score trained model
scores = model.evaluate(x_test,
                        y_test,
                        batch_size=batch_size,
                        verbose=0)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Using real-time data augmentation.
# Epoch 1/300
# Learning rate:  0.1
#   6/391 [..............................] - ETA: 2:39 - loss: 27.4697 - acc: 0.1029WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1455s vs `on_train_batch_end` time: 0.2251s). Check your callbacks.
# 391/391 [==============================] - 222s 471ms/step - loss: 14.4920 - acc: 0.2338 - val_loss: 10.2136 - val_acc: 0.1654
#
# Epoch 00001: val_acc improved from -inf to 0.16540, saving model to /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300/cifar10_ResNext29_2x64d_e300.h5
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/300
# Learning rate:  0.1
# 391/391 [==============================] - 181s 464ms/step - loss: 7.2742 - acc: 0.3955 - val_loss: 6.2142 - val_acc: 0.2203
#
# Epoch 00002: val_acc improved from 0.16540 to 0.22030, saving model to /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300/cifar10_ResNext29_2x64d_e300.h5
# Epoch 3/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 4.0466 - acc: 0.4956 - val_loss: 3.3251 - val_acc: 0.4490
#
# Epoch 00003: val_acc improved from 0.22030 to 0.44900, saving model to /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300/cifar10_ResNext29_2x64d_e300.h5
# Epoch 4/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 2.5233 - acc: 0.5723 - val_loss: 2.0892 - val_acc: 0.6104
#
# Epoch 00004: val_acc improved from 0.44900 to 0.61040, saving model to /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300/cifar10_ResNext29_2x64d_e300.h5
# Epoch 5/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 1.7845 - acc: 0.6321 - val_loss: 1.8328 - val_acc: 0.5739
#
# Epoch 00005: val_acc did not improve from 0.61040
# Epoch 6/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 1.4120 - acc: 0.6799 - val_loss: 1.7334 - val_acc: 0.5821
#
# Epoch 00006: val_acc did not improve from 0.61040
# Epoch 7/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 1.2203 - acc: 0.7180 - val_loss: 3.6200 - val_acc: 0.5182
#
# Epoch 00007: val_acc did not improve from 0.61040
# Epoch 8/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 1.1220 - acc: 0.7424 - val_loss: 2.0415 - val_acc: 0.5606
#
# Epoch 00008: val_acc did not improve from 0.61040
# Epoch 9/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 1.0526 - acc: 0.7617 - val_loss: 1.2156 - val_acc: 0.7061
#
# Epoch 00009: val_acc improved from 0.61040 to 0.70610, saving model to /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300/cifar10_ResNext29_2x64d_e300.h5
# Epoch 10/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 1.0303 - acc: 0.7691 - val_loss: 1.7049 - val_acc: 0.6281
#
# Epoch 00010: val_acc did not improve from 0.70610
# Epoch 11/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 1.0023 - acc: 0.7811 - val_loss: 1.2917 - val_acc: 0.6915
#
# Epoch 00011: val_acc did not improve from 0.70610
# Epoch 12/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.9918 - acc: 0.7885 - val_loss: 1.2535 - val_acc: 0.7058
#
# Epoch 00012: val_acc did not improve from 0.70610
# Epoch 13/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 0.9760 - acc: 0.7933 - val_loss: 1.2791 - val_acc: 0.7021
#
# Epoch 00013: val_acc did not improve from 0.70610
# Epoch 14/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.9713 - acc: 0.7967 - val_loss: 1.2215 - val_acc: 0.7208
#
# Epoch 00014: val_acc improved from 0.70610 to 0.72080, saving model to /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300/cifar10_ResNext29_2x64d_e300.h5
# Epoch 15/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 467ms/step - loss: 0.9663 - acc: 0.8024 - val_loss: 1.1727 - val_acc: 0.7493
#
# Epoch 00015: val_acc improved from 0.72080 to 0.74930, saving model to /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300/cifar10_ResNext29_2x64d_e300.h5
# Epoch 16/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.9534 - acc: 0.8076 - val_loss: 1.5400 - val_acc: 0.6591
#
# Epoch 00016: val_acc did not improve from 0.74930
# Epoch 17/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.9357 - acc: 0.8122 - val_loss: 1.1167 - val_acc: 0.7501
#
# Epoch 00017: val_acc improved from 0.74930 to 0.75010, saving model to /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300/cifar10_ResNext29_2x64d_e300.h5
# Epoch 18/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.9482 - acc: 0.8135 - val_loss: 1.2394 - val_acc: 0.7265
#
# Epoch 00018: val_acc did not improve from 0.75010
# Epoch 19/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 0.9407 - acc: 0.8147 - val_loss: 1.2108 - val_acc: 0.7416
#
# Epoch 00019: val_acc did not improve from 0.75010
# Epoch 20/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.9294 - acc: 0.8223 - val_loss: 2.0594 - val_acc: 0.5570
#
# Epoch 00020: val_acc did not improve from 0.75010
# Epoch 21/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 0.9471 - acc: 0.8181 - val_loss: 1.7961 - val_acc: 0.6421
#
# Epoch 00021: val_acc did not improve from 0.75010
# Epoch 22/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.9381 - acc: 0.8226 - val_loss: 1.0685 - val_acc: 0.7685
#
# Epoch 00022: val_acc improved from 0.75010 to 0.76850, saving model to /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300/cifar10_ResNext29_2x64d_e300.h5
# Epoch 23/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 467ms/step - loss: 0.9290 - acc: 0.8233 - val_loss: 1.1376 - val_acc: 0.7647
#
# Epoch 00023: val_acc did not improve from 0.76850
# Epoch 24/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 0.9345 - acc: 0.8252 - val_loss: 1.4077 - val_acc: 0.6931
#
# Epoch 00024: val_acc did not improve from 0.76850
# Epoch 25/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 467ms/step - loss: 0.9229 - acc: 0.8288 - val_loss: 1.1604 - val_acc: 0.7552
#
# Epoch 00025: val_acc did not improve from 0.76850
# Epoch 26/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 0.9221 - acc: 0.8295 - val_loss: 1.2649 - val_acc: 0.7222
#
# Epoch 00026: val_acc did not improve from 0.76850
# Epoch 27/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 0.9168 - acc: 0.8332 - val_loss: 1.1388 - val_acc: 0.7614
#
# Epoch 00027: val_acc did not improve from 0.76850
# Epoch 28/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 467ms/step - loss: 0.9161 - acc: 0.8345 - val_loss: 1.2139 - val_acc: 0.7330
#
# Epoch 00028: val_acc did not improve from 0.76850
# Epoch 29/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 0.9072 - acc: 0.8328 - val_loss: 1.1919 - val_acc: 0.7461
#
# Epoch 00029: val_acc did not improve from 0.76850
# Epoch 30/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 468ms/step - loss: 0.9028 - acc: 0.8375 - val_loss: 1.8838 - val_acc: 0.6498
#
# Epoch 00030: val_acc did not improve from 0.76850
# Epoch 31/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 468ms/step - loss: 0.9054 - acc: 0.8368 - val_loss: 1.3538 - val_acc: 0.7275
#
# Epoch 00031: val_acc did not improve from 0.76850
# Epoch 32/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 468ms/step - loss: 0.9047 - acc: 0.8365 - val_loss: 1.1574 - val_acc: 0.7533
#
# Epoch 00032: val_acc did not improve from 0.76850
# Epoch 33/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 468ms/step - loss: 0.9021 - acc: 0.8393 - val_loss: 1.8409 - val_acc: 0.6688
#
# Epoch 00033: val_acc did not improve from 0.76850
# Epoch 34/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 0.8973 - acc: 0.8407 - val_loss: 1.1291 - val_acc: 0.7624
#
# Epoch 00034: val_acc did not improve from 0.76850
# Epoch 35/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 0.8997 - acc: 0.8409 - val_loss: 1.1121 - val_acc: 0.7772
#
# Epoch 00035: val_acc improved from 0.76850 to 0.77720, saving model to /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300/cifar10_ResNext29_2x64d_e300.h5
# Epoch 36/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 468ms/step - loss: 0.8985 - acc: 0.8425 - val_loss: 1.1706 - val_acc: 0.7512
#
# Epoch 00036: val_acc did not improve from 0.77720
# Epoch 37/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 0.8947 - acc: 0.8447 - val_loss: 1.2499 - val_acc: 0.7290
#
# Epoch 00037: val_acc did not improve from 0.77720
# Epoch 38/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 0.8956 - acc: 0.8445 - val_loss: 1.1100 - val_acc: 0.7727
#
# Epoch 00038: val_acc did not improve from 0.77720
# Epoch 39/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 0.8984 - acc: 0.8430 - val_loss: 1.0925 - val_acc: 0.7863
#
# Epoch 00039: val_acc improved from 0.77720 to 0.78630, saving model to /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300/cifar10_ResNext29_2x64d_e300.h5
# Epoch 40/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 468ms/step - loss: 0.8981 - acc: 0.8461 - val_loss: 1.2999 - val_acc: 0.7252
#
# Epoch 00040: val_acc did not improve from 0.78630
# Epoch 41/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 468ms/step - loss: 0.8963 - acc: 0.8458 - val_loss: 1.3870 - val_acc: 0.7224
#
# Epoch 00041: val_acc did not improve from 0.78630
# Epoch 42/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 0.8983 - acc: 0.8456 - val_loss: 1.1980 - val_acc: 0.7611
#
# Epoch 00042: val_acc did not improve from 0.78630
# Epoch 43/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8927 - acc: 0.8484 - val_loss: 1.5167 - val_acc: 0.6597
#
# Epoch 00043: val_acc did not improve from 0.78630
# Epoch 44/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8976 - acc: 0.8471 - val_loss: 1.0498 - val_acc: 0.8003
#
# Epoch 00044: val_acc improved from 0.78630 to 0.80030, saving model to /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300/cifar10_ResNext29_2x64d_e300.h5
# Epoch 45/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8907 - acc: 0.8485 - val_loss: 1.2859 - val_acc: 0.7579
#
# Epoch 00045: val_acc did not improve from 0.80030
# Epoch 46/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 467ms/step - loss: 0.8875 - acc: 0.8513 - val_loss: 1.2162 - val_acc: 0.7712
#
# Epoch 00046: val_acc did not improve from 0.80030
# Epoch 47/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8937 - acc: 0.8517 - val_loss: 1.4204 - val_acc: 0.6855
#
# Epoch 00047: val_acc did not improve from 0.80030
# Epoch 48/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8951 - acc: 0.8514 - val_loss: 1.3170 - val_acc: 0.7179
#
# Epoch 00048: val_acc did not improve from 0.80030
# Epoch 49/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 0.8897 - acc: 0.8526 - val_loss: 1.1888 - val_acc: 0.7642
#
# Epoch 00049: val_acc did not improve from 0.80030
# Epoch 50/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8926 - acc: 0.8528 - val_loss: 1.6356 - val_acc: 0.6947
#
# Epoch 00050: val_acc did not improve from 0.80030
# Epoch 51/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 467ms/step - loss: 0.8982 - acc: 0.8492 - val_loss: 1.0210 - val_acc: 0.8146
#
# Epoch 00051: val_acc improved from 0.80030 to 0.81460, saving model to /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300/cifar10_ResNext29_2x64d_e300.h5
# Epoch 52/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8897 - acc: 0.8525 - val_loss: 1.5118 - val_acc: 0.6905
#
# Epoch 00052: val_acc did not improve from 0.81460
# Epoch 53/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8935 - acc: 0.8516 - val_loss: 1.1303 - val_acc: 0.7813
#
# Epoch 00053: val_acc did not improve from 0.81460
# Epoch 54/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8818 - acc: 0.8570 - val_loss: 1.1905 - val_acc: 0.7601
#
# Epoch 00054: val_acc did not improve from 0.81460
# Epoch 55/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8826 - acc: 0.8545 - val_loss: 1.1306 - val_acc: 0.7847
#
# Epoch 00055: val_acc did not improve from 0.81460
# Epoch 56/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8905 - acc: 0.8536 - val_loss: 1.1995 - val_acc: 0.7633
#
# Epoch 00056: val_acc did not improve from 0.81460
# Epoch 57/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8841 - acc: 0.8552 - val_loss: 1.0312 - val_acc: 0.8141
#
# Epoch 00057: val_acc did not improve from 0.81460
# Epoch 58/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8906 - acc: 0.8557 - val_loss: 1.3842 - val_acc: 0.7076
#
# Epoch 00058: val_acc did not improve from 0.81460
# Epoch 59/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8920 - acc: 0.8568 - val_loss: 1.4482 - val_acc: 0.7188
#
# Epoch 00059: val_acc did not improve from 0.81460
# Epoch 60/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8827 - acc: 0.8572 - val_loss: 1.1120 - val_acc: 0.7820
#
# Epoch 00060: val_acc did not improve from 0.81460
# Epoch 61/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8832 - acc: 0.8584 - val_loss: 1.1790 - val_acc: 0.7601
#
# Epoch 00061: val_acc did not improve from 0.81460
# Epoch 62/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8868 - acc: 0.8563 - val_loss: 1.3026 - val_acc: 0.7513
#
# Epoch 00062: val_acc did not improve from 0.81460
# Epoch 63/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8771 - acc: 0.8601 - val_loss: 1.2460 - val_acc: 0.7587
#
# Epoch 00063: val_acc did not improve from 0.81460
# Epoch 64/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8847 - acc: 0.8574 - val_loss: 1.0083 - val_acc: 0.8170
#
# Epoch 00064: val_acc improved from 0.81460 to 0.81700, saving model to /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300/cifar10_ResNext29_2x64d_e300.h5
# Epoch 65/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8799 - acc: 0.8594 - val_loss: 1.5121 - val_acc: 0.7025
#
# Epoch 00065: val_acc did not improve from 0.81700
# Epoch 66/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8819 - acc: 0.8594 - val_loss: 1.1624 - val_acc: 0.7882
#
# Epoch 00066: val_acc did not improve from 0.81700
# Epoch 67/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8821 - acc: 0.8604 - val_loss: 1.2091 - val_acc: 0.7576
#
# Epoch 00067: val_acc did not improve from 0.81700
# Epoch 68/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8820 - acc: 0.8598 - val_loss: 1.0912 - val_acc: 0.7959
#
# Epoch 00068: val_acc did not improve from 0.81700
# Epoch 69/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8758 - acc: 0.8618 - val_loss: 1.2152 - val_acc: 0.7786
#
# Epoch 00069: val_acc did not improve from 0.81700
# Epoch 70/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8764 - acc: 0.8604 - val_loss: 1.1603 - val_acc: 0.7680
#
# Epoch 00070: val_acc did not improve from 0.81700
# Epoch 71/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8816 - acc: 0.8592 - val_loss: 1.3033 - val_acc: 0.7606
#
# Epoch 00071: val_acc did not improve from 0.81700
# Epoch 72/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8783 - acc: 0.8614 - val_loss: 1.2036 - val_acc: 0.7599
#
# Epoch 00072: val_acc did not improve from 0.81700
# Epoch 73/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8814 - acc: 0.8599 - val_loss: 1.1449 - val_acc: 0.7681
#
# Epoch 00073: val_acc did not improve from 0.81700
# Epoch 74/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8851 - acc: 0.8614 - val_loss: 1.9994 - val_acc: 0.6203
#
# Epoch 00074: val_acc did not improve from 0.81700
# Epoch 75/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8836 - acc: 0.8618 - val_loss: 1.3267 - val_acc: 0.7394
#
# Epoch 00075: val_acc did not improve from 0.81700
# Epoch 76/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8801 - acc: 0.8625 - val_loss: 1.1708 - val_acc: 0.7758
#
# Epoch 00076: val_acc did not improve from 0.81700
# Epoch 77/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8770 - acc: 0.8625 - val_loss: 1.5938 - val_acc: 0.6860
#
# Epoch 00077: val_acc did not improve from 0.81700
# Epoch 78/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8796 - acc: 0.8614 - val_loss: 1.2106 - val_acc: 0.7639
#
# Epoch 00078: val_acc did not improve from 0.81700
# Epoch 79/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8799 - acc: 0.8620 - val_loss: 1.2125 - val_acc: 0.7679
#
# Epoch 00079: val_acc did not improve from 0.81700
# Epoch 80/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 464ms/step - loss: 0.8782 - acc: 0.8635 - val_loss: 1.1677 - val_acc: 0.7632
#
# Epoch 00080: val_acc did not improve from 0.81700
# Epoch 81/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 464ms/step - loss: 0.8862 - acc: 0.8617 - val_loss: 1.1640 - val_acc: 0.7865
#
# Epoch 00081: val_acc did not improve from 0.81700
# Epoch 82/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8832 - acc: 0.8625 - val_loss: 1.0436 - val_acc: 0.8142
#
# Epoch 00082: val_acc did not improve from 0.81700
# Epoch 83/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8803 - acc: 0.8646 - val_loss: 1.1488 - val_acc: 0.7811
#
# Epoch 00083: val_acc did not improve from 0.81700
# Epoch 84/300
# Learning rate:  0.1
# 391/391 [==============================] - 181s 464ms/step - loss: 0.8794 - acc: 0.8639 - val_loss: 1.4337 - val_acc: 0.7086
#
# Epoch 00084: val_acc did not improve from 0.81700
# Epoch 85/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8726 - acc: 0.8662 - val_loss: 1.1670 - val_acc: 0.7778
#
# Epoch 00085: val_acc did not improve from 0.81700
# Epoch 86/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8804 - acc: 0.8647 - val_loss: 1.3218 - val_acc: 0.7473
#
# Epoch 00086: val_acc did not improve from 0.81700
# Epoch 87/300
# Learning rate:  0.1
# 391/391 [==============================] - 181s 464ms/step - loss: 0.8746 - acc: 0.8647 - val_loss: 1.3359 - val_acc: 0.7593
#
# Epoch 00087: val_acc did not improve from 0.81700
# Epoch 88/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8727 - acc: 0.8667 - val_loss: 1.4162 - val_acc: 0.7156
#
# Epoch 00088: val_acc did not improve from 0.81700
# Epoch 89/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8625 - acc: 0.8674 - val_loss: 1.1665 - val_acc: 0.7706
#
# Epoch 00089: val_acc did not improve from 0.81700
# Epoch 90/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8701 - acc: 0.8662 - val_loss: 1.0841 - val_acc: 0.7949
#
# Epoch 00090: val_acc did not improve from 0.81700
# Epoch 91/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8632 - acc: 0.8692 - val_loss: 1.1753 - val_acc: 0.7668
#
# Epoch 00091: val_acc did not improve from 0.81700
# Epoch 92/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8694 - acc: 0.8645 - val_loss: 1.2874 - val_acc: 0.7315
#
# Epoch 00092: val_acc did not improve from 0.81700
# Epoch 93/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8662 - acc: 0.8676 - val_loss: 1.5737 - val_acc: 0.6677
#
# Epoch 00093: val_acc did not improve from 0.81700
# Epoch 94/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8727 - acc: 0.8664 - val_loss: 1.3134 - val_acc: 0.7529
#
# Epoch 00094: val_acc did not improve from 0.81700
# Epoch 95/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8711 - acc: 0.8671 - val_loss: 1.2140 - val_acc: 0.7612
#
# Epoch 00095: val_acc did not improve from 0.81700
# Epoch 96/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8653 - acc: 0.8677 - val_loss: 1.0720 - val_acc: 0.7863
#
# Epoch 00096: val_acc did not improve from 0.81700
# Epoch 97/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8576 - acc: 0.8671 - val_loss: 1.1577 - val_acc: 0.7811
#
# Epoch 00097: val_acc did not improve from 0.81700
# Epoch 98/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8615 - acc: 0.8651 - val_loss: 1.3733 - val_acc: 0.7263
#
# Epoch 00098: val_acc did not improve from 0.81700
# Epoch 99/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8561 - acc: 0.8706 - val_loss: 1.2675 - val_acc: 0.7454
#
# Epoch 00099: val_acc did not improve from 0.81700
# Epoch 100/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8578 - acc: 0.8683 - val_loss: 1.1250 - val_acc: 0.7858
#
# Epoch 00100: val_acc did not improve from 0.81700
# Epoch 101/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8496 - acc: 0.8710 - val_loss: 1.5542 - val_acc: 0.6965
#
# Epoch 00101: val_acc did not improve from 0.81700
# Epoch 102/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8539 - acc: 0.8703 - val_loss: 1.2473 - val_acc: 0.7513
#
# Epoch 00102: val_acc did not improve from 0.81700
# Epoch 103/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8561 - acc: 0.8684 - val_loss: 1.0582 - val_acc: 0.8084
#
# Epoch 00103: val_acc did not improve from 0.81700
# Epoch 104/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 467ms/step - loss: 0.8513 - acc: 0.8714 - val_loss: 1.0845 - val_acc: 0.7983
#
# Epoch 00104: val_acc did not improve from 0.81700
# Epoch 105/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8561 - acc: 0.8685 - val_loss: 1.1493 - val_acc: 0.7731
#
# Epoch 00105: val_acc did not improve from 0.81700
# Epoch 106/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8564 - acc: 0.8699 - val_loss: 1.6535 - val_acc: 0.6614
#
# Epoch 00106: val_acc did not improve from 0.81700
# Epoch 107/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8535 - acc: 0.8705 - val_loss: 1.0480 - val_acc: 0.8049
#
# Epoch 00107: val_acc did not improve from 0.81700
# Epoch 108/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 0.8495 - acc: 0.8720 - val_loss: 1.2670 - val_acc: 0.7583
#
# Epoch 00108: val_acc did not improve from 0.81700
# Epoch 109/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8575 - acc: 0.8686 - val_loss: 1.1733 - val_acc: 0.7717
#
# Epoch 00109: val_acc did not improve from 0.81700
# Epoch 110/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 467ms/step - loss: 0.8544 - acc: 0.8717 - val_loss: 1.2768 - val_acc: 0.7481
#
# Epoch 00110: val_acc did not improve from 0.81700
# Epoch 111/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 468ms/step - loss: 0.8617 - acc: 0.8696 - val_loss: 1.1382 - val_acc: 0.7880
#
# Epoch 00111: val_acc did not improve from 0.81700
# Epoch 112/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8512 - acc: 0.8696 - val_loss: 1.3437 - val_acc: 0.7213
#
# Epoch 00112: val_acc did not improve from 0.81700
# Epoch 113/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 0.8599 - acc: 0.8691 - val_loss: 1.0822 - val_acc: 0.7991
#
# Epoch 00113: val_acc did not improve from 0.81700
# Epoch 114/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 468ms/step - loss: 0.8498 - acc: 0.8706 - val_loss: 1.7099 - val_acc: 0.6653
#
# Epoch 00114: val_acc did not improve from 0.81700
# Epoch 115/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 468ms/step - loss: 0.8501 - acc: 0.8702 - val_loss: 1.4008 - val_acc: 0.7009
#
# Epoch 00115: val_acc did not improve from 0.81700
# Epoch 116/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8523 - acc: 0.8709 - val_loss: 1.1053 - val_acc: 0.7971
#
# Epoch 00116: val_acc did not improve from 0.81700
# Epoch 117/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8536 - acc: 0.8709 - val_loss: 1.2478 - val_acc: 0.7581
#
# Epoch 00117: val_acc did not improve from 0.81700
# Epoch 118/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8481 - acc: 0.8718 - val_loss: 1.2778 - val_acc: 0.7531
#
# Epoch 00118: val_acc did not improve from 0.81700
# Epoch 119/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8489 - acc: 0.8707 - val_loss: 1.0928 - val_acc: 0.7944
#
# Epoch 00119: val_acc did not improve from 0.81700
# Epoch 120/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 467ms/step - loss: 0.8591 - acc: 0.8687 - val_loss: 1.0721 - val_acc: 0.8048
#
# Epoch 00120: val_acc did not improve from 0.81700
# Epoch 121/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8526 - acc: 0.8710 - val_loss: 1.0268 - val_acc: 0.8125
#
# Epoch 00121: val_acc did not improve from 0.81700
# Epoch 122/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 0.8528 - acc: 0.8706 - val_loss: 1.3150 - val_acc: 0.7364
#
# Epoch 00122: val_acc did not improve from 0.81700
# Epoch 123/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8474 - acc: 0.8737 - val_loss: 1.2053 - val_acc: 0.7662
#
# Epoch 00123: val_acc did not improve from 0.81700
# Epoch 124/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 0.8502 - acc: 0.8725 - val_loss: 1.0783 - val_acc: 0.8034
#
# Epoch 00124: val_acc did not improve from 0.81700
# Epoch 125/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8505 - acc: 0.8709 - val_loss: 1.0362 - val_acc: 0.8177
#
# Epoch 00125: val_acc improved from 0.81700 to 0.81770, saving model to /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300/cifar10_ResNext29_2x64d_e300.h5
# Epoch 126/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8457 - acc: 0.8727 - val_loss: 1.1400 - val_acc: 0.7826
#
# Epoch 00126: val_acc did not improve from 0.81770
# Epoch 127/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8518 - acc: 0.8708 - val_loss: 1.3723 - val_acc: 0.7195
#
# Epoch 00127: val_acc did not improve from 0.81770
# Epoch 128/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8512 - acc: 0.8718 - val_loss: 1.2134 - val_acc: 0.7636
#
# Epoch 00128: val_acc did not improve from 0.81770
# Epoch 129/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8544 - acc: 0.8710 - val_loss: 0.9552 - val_acc: 0.8380
#
# Epoch 00129: val_acc improved from 0.81770 to 0.83800, saving model to /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300/cifar10_ResNext29_2x64d_e300.h5
# Epoch 130/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8499 - acc: 0.8712 - val_loss: 1.1656 - val_acc: 0.7696
#
# Epoch 00130: val_acc did not improve from 0.83800
# Epoch 131/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8498 - acc: 0.8733 - val_loss: 1.2152 - val_acc: 0.7655
#
# Epoch 00131: val_acc did not improve from 0.83800
# Epoch 132/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8466 - acc: 0.8732 - val_loss: 1.2869 - val_acc: 0.7311
#
# Epoch 00132: val_acc did not improve from 0.83800
# Epoch 133/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 0.8532 - acc: 0.8723 - val_loss: 1.3336 - val_acc: 0.7292
#
# Epoch 00133: val_acc did not improve from 0.83800
# Epoch 134/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 0.8441 - acc: 0.8736 - val_loss: 1.4104 - val_acc: 0.7286
#
# Epoch 00134: val_acc did not improve from 0.83800
# Epoch 135/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8437 - acc: 0.8731 - val_loss: 1.1420 - val_acc: 0.7730
#
# Epoch 00135: val_acc did not improve from 0.83800
# Epoch 136/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8432 - acc: 0.8738 - val_loss: 1.2047 - val_acc: 0.7624
#
# Epoch 00136: val_acc did not improve from 0.83800
# Epoch 137/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8496 - acc: 0.8721 - val_loss: 1.4037 - val_acc: 0.7163
#
# Epoch 00137: val_acc did not improve from 0.83800
# Epoch 138/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8476 - acc: 0.8733 - val_loss: 1.2919 - val_acc: 0.7466
#
# Epoch 00138: val_acc did not improve from 0.83800
# Epoch 139/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8552 - acc: 0.8711 - val_loss: 1.3327 - val_acc: 0.7419
#
# Epoch 00139: val_acc did not improve from 0.83800
# Epoch 140/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8474 - acc: 0.8734 - val_loss: 1.2048 - val_acc: 0.7766
#
# Epoch 00140: val_acc did not improve from 0.83800
# Epoch 141/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8404 - acc: 0.8759 - val_loss: 1.3086 - val_acc: 0.7561
#
# Epoch 00141: val_acc did not improve from 0.83800
# Epoch 142/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8502 - acc: 0.8717 - val_loss: 1.0802 - val_acc: 0.7994
#
# Epoch 00142: val_acc did not improve from 0.83800
# Epoch 143/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8602 - acc: 0.8712 - val_loss: 1.0687 - val_acc: 0.8104
#
# Epoch 00143: val_acc did not improve from 0.83800
# Epoch 144/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8448 - acc: 0.8763 - val_loss: 1.1448 - val_acc: 0.7835
#
# Epoch 00144: val_acc did not improve from 0.83800
# Epoch 145/300
# Learning rate:  0.1
# 391/391 [==============================] - 183s 467ms/step - loss: 0.8476 - acc: 0.8721 - val_loss: 1.0955 - val_acc: 0.7981
#
# Epoch 00145: val_acc did not improve from 0.83800
# Epoch 146/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8485 - acc: 0.8727 - val_loss: 1.1317 - val_acc: 0.7856
#
# Epoch 00146: val_acc did not improve from 0.83800
# Epoch 147/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8482 - acc: 0.8726 - val_loss: 1.1631 - val_acc: 0.7763
#
# Epoch 00147: val_acc did not improve from 0.83800
# Epoch 148/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8482 - acc: 0.8729 - val_loss: 1.0285 - val_acc: 0.8170
#
# Epoch 00148: val_acc did not improve from 0.83800
# Epoch 149/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 467ms/step - loss: 0.8372 - acc: 0.8750 - val_loss: 1.0179 - val_acc: 0.8137
#
# Epoch 00149: val_acc did not improve from 0.83800
# Epoch 150/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8511 - acc: 0.8708 - val_loss: 1.6264 - val_acc: 0.6615
#
# Epoch 00150: val_acc did not improve from 0.83800
# Epoch 151/300
# Learning rate:  0.010000000000000002
# 391/391 [==============================] - 182s 465ms/step - loss: 0.7137 - acc: 0.9168 - val_loss: 0.7258 - val_acc: 0.9105
#
# Epoch 00151: val_acc improved from 0.83800 to 0.91050, saving model to /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300/cifar10_ResNext29_2x64d_e300.h5
# Epoch 152/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8263 - acc: 0.8745 - val_loss: 1.3204 - val_acc: 0.7385
#
# Epoch 00152: val_acc did not improve from 0.91050
# Epoch 153/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8422 - acc: 0.8740 - val_loss: 1.1967 - val_acc: 0.7597
#
# Epoch 00153: val_acc did not improve from 0.91050
# Epoch 154/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8481 - acc: 0.8710 - val_loss: 1.3955 - val_acc: 0.7042
#
# Epoch 00154: val_acc did not improve from 0.91050
# Epoch 155/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8498 - acc: 0.8730 - val_loss: 1.3990 - val_acc: 0.7163
#
# Epoch 00155: val_acc did not improve from 0.91050
# Epoch 156/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8536 - acc: 0.8733 - val_loss: 1.1165 - val_acc: 0.7962
#
# Epoch 00156: val_acc did not improve from 0.91050
# Epoch 157/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8389 - acc: 0.8763 - val_loss: 1.6935 - val_acc: 0.6852
#
# Epoch 00157: val_acc did not improve from 0.91050
# Epoch 158/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8409 - acc: 0.8755 - val_loss: 1.5382 - val_acc: 0.7104
#
# Epoch 00158: val_acc did not improve from 0.91050
# Epoch 159/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8463 - acc: 0.8744 - val_loss: 1.1388 - val_acc: 0.7856
#
# Epoch 00159: val_acc did not improve from 0.91050
# Epoch 160/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8448 - acc: 0.8750 - val_loss: 1.4009 - val_acc: 0.7437
#
# Epoch 00160: val_acc did not improve from 0.91050
# Epoch 161/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8411 - acc: 0.8739 - val_loss: 1.3179 - val_acc: 0.7485
#
# Epoch 00161: val_acc did not improve from 0.91050
# Epoch 162/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8490 - acc: 0.8749 - val_loss: 1.0587 - val_acc: 0.8157
#
# Epoch 00162: val_acc did not improve from 0.91050
# Epoch 163/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8467 - acc: 0.8737 - val_loss: 1.1356 - val_acc: 0.7766
#
# Epoch 00163: val_acc did not improve from 0.91050
# Epoch 164/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 466ms/step - loss: 0.8351 - acc: 0.8768 - val_loss: 1.1618 - val_acc: 0.7692
#
# Epoch 00164: val_acc did not improve from 0.91050
# Epoch 165/300
# Learning rate:  0.1
# 391/391 [==============================] - 182s 465ms/step - loss: 0.8427 - acc: 0.8732 - val_loss: 1.1304 - val_acc: 0.7983
#
# Epoch 00165: val_acc did not improve from 0.91050
# Epoch 166/300
# Learning rate:  0.1
# 265/391 [===================>..........] - ETA: 55s - loss: 0.8393 - acc: 0.8764

# %%
# Plot data
EPOCH = 200 # number of epochs the model has trained for

ex_history_df = pd.read_csv('/content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64de100' + 
                            '/model_history.csv', sep=',')
history_df = pd.read_csv('/content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e200' + 
                         '/model_history.csv', sep=',') # model_directory

# Plot training & validation error values
plt.style.use("ggplot")
EPOCH = 79
plt.plot(range(1, EPOCH + 1),
         1 - ex_history_df['acc'], 'b')
plt.plot(range(1, EPOCH + 1),
         1 - ex_history_df['val_acc'], 'b', 
         linestyle='--')
EPOCH = 81
plt.plot(range(1, EPOCH + 1),
         1 - history_df['acc'], 'r')
plt.plot(range(1, EPOCH + 1),
         1 - history_df['val_acc'], 'r', 
         linestyle='--')
plt.title('Model error')
plt.ylabel('Error')
plt.xlabel('Epoch')
legend_1 = plt.legend(['ResNet20v1_Train', 'ResNet20v1_Test', 'ResNet20v2_Train', 'ResNet20v2_Test'], loc='upper right')
plt.annotate('%.4f' % float(1 - history_df['val_acc'][-1:]), xy=(1, float(1 - history_df['val_acc'][-1:])), xytext=(8, -6), 
              xycoords=('axes fraction', 'data'), textcoords='offset points')
plt.annotate('%.4f' % float(1 - ex_history_df['val_acc'][-1:]), xy=(1, float(1 - ex_history_df['val_acc'][-1:])), xytext=(8, 6), 
              xycoords=('axes fraction', 'data'), textcoords='offset points')
plt.show()

# %%
loaded_model = tf.keras.models.load_model(filepath)
loaded_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   1792        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 128)  8320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 128)  512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 128)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 128)  73856       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 256)  16640       activation[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 256)  33024       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 256)  1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 256)  0           batch_normalization_4[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 256)  0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 128)  32896       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 128)  73856       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 256)  33024       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 256)  0           activation_3[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 128)  32896       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 128)  73856       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 256)  33024       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 256)  0           activation_6[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 256)  65792       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 256)  295168      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 256)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 512)  131584      activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 512)  131584      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 512)  2048        conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 512)  2048        conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 512)  0           batch_normalization_14[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 512)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 256)  131328      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 256)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 256)  295168      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 16, 256)  1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 512)  131584      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 512)  2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 512)  0           activation_12[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 16, 16, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 256)  131328      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 16, 256)  1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 16, 16, 256)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 256)  295168      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 16, 256)  1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 16, 16, 256)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 16, 16, 512)  131584      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 16, 16, 512)  2048        conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 512)  0           activation_15[0][0]
#                                                                  batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 16, 16, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 512)    262656      activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 8, 8, 512)    2048        conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 512)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 512)    1180160     activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 8, 8, 512)    2048        conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 8, 8, 512)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 8, 1024)   525312      activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 8, 1024)   525312      activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 8, 8, 1024)   4096        conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 8, 8, 1024)   4096        conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 1024)   0           batch_normalization_24[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 8, 8, 1024)   0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 8, 512)    524800      activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 8, 512)    2048        conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 8, 8, 512)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 8, 8, 512)    1180160     activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 8, 512)    2048        conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 8, 8, 512)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 8, 8, 1024)   525312      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 8, 1024)   4096        conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 1024)   0           activation_21[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 8, 8, 1024)   0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 512)    524800      activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 8, 8, 512)    2048        conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 8, 8, 512)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 512)    1180160     activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 8, 8, 512)    2048        conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 8, 8, 512)    0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 8, 8, 1024)   525312      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 8, 8, 1024)   4096        conv2d_30[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 1024)   0           activation_24[0][0]
#                                                                  batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 8, 8, 1024)   0           add_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 1024)   0           activation_27[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           10250       flatten[0][0]
# ==================================================================================================
# Total params: 9,168,138
# Trainable params: 9,142,922
# Non-trainable params: 25,216
# __________________________________________________________________________________________________

# %%
# update the learning rate
print("[INFO] old learning rate: {}".format(
    K.get_value(model.optimizer.lr)))

# %%
epochs = 200

# run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    loaded_model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # this will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False)

    # compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    steps_per_epoch =  math.ceil(len(x_train) / batch_size)
    # fit the model on the batches generated by datagen.flow().
    loaded_model.fit(x=datagen.flow(x_train, y_train, batch_size=batch_size),
              verbose=1,
              epochs=epochs,
              validation_data=(x_test, y_test),
              steps_per_epoch=steps_per_epoch,
              callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Epoch 1/200
#   6/391 [..............................] - ETA: 2:36 - loss: 0.1216 - acc: 1.0000WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1439s vs `on_train_batch_end` time: 0.2182s). Check your callbacks.
# 391/391 [==============================] - 216s 458ms/step - loss: 0.1228 - acc: 0.9993 - val_loss: 0.4365 - val_acc: 0.9390
#
# Epoch 00001: val_acc improved from -inf to 0.93900, saving model to /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300/cifar10_ResNext29_2x64d_e300.h5
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1226 - acc: 0.9991 - val_loss: 0.4383 - val_acc: 0.9387
#
# Epoch 00002: val_acc did not improve from 0.93900
# Epoch 3/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1217 - acc: 0.9993 - val_loss: 0.4392 - val_acc: 0.9391
#
# Epoch 00003: val_acc improved from 0.93900 to 0.93910, saving model to /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300/cifar10_ResNext29_2x64d_e300.h5
# Epoch 4/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1214 - acc: 0.9992 - val_loss: 0.4374 - val_acc: 0.9383
#
# Epoch 00004: val_acc did not improve from 0.93910
# Epoch 5/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1209 - acc: 0.9993 - val_loss: 0.4391 - val_acc: 0.9380
#
# Epoch 00005: val_acc did not improve from 0.93910
# Epoch 6/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1209 - acc: 0.9992 - val_loss: 0.4459 - val_acc: 0.9382
#
# Epoch 00006: val_acc did not improve from 0.93910
# Epoch 7/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1203 - acc: 0.9993 - val_loss: 0.4487 - val_acc: 0.9372
#
# Epoch 00007: val_acc did not improve from 0.93910
# Epoch 8/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1202 - acc: 0.9993 - val_loss: 0.4491 - val_acc: 0.9381
#
# Epoch 00008: val_acc did not improve from 0.93910
# Epoch 9/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1198 - acc: 0.9992 - val_loss: 0.4411 - val_acc: 0.9386
#
# Epoch 00009: val_acc did not improve from 0.93910
# Epoch 10/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1191 - acc: 0.9993 - val_loss: 0.4469 - val_acc: 0.9383
#
# Epoch 00010: val_acc did not improve from 0.93910
# Epoch 11/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1191 - acc: 0.9992 - val_loss: 0.4441 - val_acc: 0.9377
#
# Epoch 00011: val_acc did not improve from 0.93910
# Epoch 12/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1184 - acc: 0.9993 - val_loss: 0.4474 - val_acc: 0.9367
#
# Epoch 00012: val_acc did not improve from 0.93910
# Epoch 13/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1183 - acc: 0.9993 - val_loss: 0.4482 - val_acc: 0.9380
#
# Epoch 00013: val_acc did not improve from 0.93910
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 3.1622778678900043e-06.
# Epoch 14/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1177 - acc: 0.9994 - val_loss: 0.4449 - val_acc: 0.9381
#
# Epoch 00014: val_acc did not improve from 0.93910
# Epoch 15/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1177 - acc: 0.9993 - val_loss: 0.4431 - val_acc: 0.9384
#
# Epoch 00015: val_acc did not improve from 0.93910
# Epoch 16/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1174 - acc: 0.9994 - val_loss: 0.4442 - val_acc: 0.9379
#
# Epoch 00016: val_acc did not improve from 0.93910
# Epoch 17/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1172 - acc: 0.9995 - val_loss: 0.4438 - val_acc: 0.9378
#
# Epoch 00017: val_acc did not improve from 0.93910
# Epoch 18/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1171 - acc: 0.9994 - val_loss: 0.4411 - val_acc: 0.9386
#
# Epoch 00018: val_acc did not improve from 0.93910
# Epoch 19/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1164 - acc: 0.9996 - val_loss: 0.4451 - val_acc: 0.9382
#
# Epoch 00019: val_acc did not improve from 0.93910
# Epoch 20/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1171 - acc: 0.9992 - val_loss: 0.4458 - val_acc: 0.9376
#
# Epoch 00020: val_acc did not improve from 0.93910
# Epoch 21/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1166 - acc: 0.9994 - val_loss: 0.4456 - val_acc: 0.9378
#
# Epoch 00021: val_acc did not improve from 0.93910
# Epoch 22/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1160 - acc: 0.9996 - val_loss: 0.4440 - val_acc: 0.9381
#
# Epoch 00022: val_acc did not improve from 0.93910
# Epoch 23/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1161 - acc: 0.9997 - val_loss: 0.4434 - val_acc: 0.9380
#
# Epoch 00023: val_acc did not improve from 0.93910
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.0000000553323957e-06.
# Epoch 24/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1162 - acc: 0.9994 - val_loss: 0.4456 - val_acc: 0.9380
#
# Epoch 00024: val_acc did not improve from 0.93910
# Epoch 25/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1161 - acc: 0.9994 - val_loss: 0.4439 - val_acc: 0.9373
#
# Epoch 00025: val_acc did not improve from 0.93910
# Epoch 26/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1160 - acc: 0.9995 - val_loss: 0.4444 - val_acc: 0.9380
#
# Epoch 00026: val_acc did not improve from 0.93910
# Epoch 27/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1159 - acc: 0.9994 - val_loss: 0.4446 - val_acc: 0.9380
#
# Epoch 00027: val_acc did not improve from 0.93910
# Epoch 28/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1159 - acc: 0.9996 - val_loss: 0.4441 - val_acc: 0.9386
#
# Epoch 00028: val_acc did not improve from 0.93910
# Epoch 29/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1157 - acc: 0.9996 - val_loss: 0.4426 - val_acc: 0.9386
#
# Epoch 00029: val_acc did not improve from 0.93910
# Epoch 30/200
# 391/391 [==============================] - 176s 451ms/step - loss: 0.1157 - acc: 0.9996 - val_loss: 0.4426 - val_acc: 0.9390
#
# Epoch 00030: val_acc did not improve from 0.93910
# Epoch 31/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1155 - acc: 0.9996 - val_loss: 0.4423 - val_acc: 0.9396
#
# Epoch 00031: val_acc improved from 0.93910 to 0.93960, saving model to /content/gdrive/My Drive/ResNet_CIFAR10_TF/saved_models/ResNext29_2x64d_e300/cifar10_ResNext29_2x64d_e300.h5
# Epoch 32/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1156 - acc: 0.9996 - val_loss: 0.4446 - val_acc: 0.9386
#
# Epoch 00032: val_acc did not improve from 0.93960
# Epoch 33/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1155 - acc: 0.9995 - val_loss: 0.4437 - val_acc: 0.9386
#
# Epoch 00033: val_acc did not improve from 0.93960
# Epoch 34/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1157 - acc: 0.9994 - val_loss: 0.4442 - val_acc: 0.9393
#
# Epoch 00034: val_acc did not improve from 0.93960
# Epoch 35/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1152 - acc: 0.9997 - val_loss: 0.4428 - val_acc: 0.9390
#
# Epoch 00035: val_acc did not improve from 0.93960
# Epoch 36/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1157 - acc: 0.9993 - val_loss: 0.4433 - val_acc: 0.9391
#
# Epoch 00036: val_acc did not improve from 0.93960
# Epoch 37/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1154 - acc: 0.9995 - val_loss: 0.4435 - val_acc: 0.9384
#
# Epoch 00037: val_acc did not improve from 0.93960
# Epoch 38/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1152 - acc: 0.9995 - val_loss: 0.4426 - val_acc: 0.9387
#
# Epoch 00038: val_acc did not improve from 0.93960
# Epoch 39/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1151 - acc: 0.9996 - val_loss: 0.4431 - val_acc: 0.9389
#
# Epoch 00039: val_acc did not improve from 0.93960
# Epoch 40/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1154 - acc: 0.9995 - val_loss: 0.4431 - val_acc: 0.9394
#
# Epoch 00040: val_acc did not improve from 0.93960
# Epoch 41/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1154 - acc: 0.9995 - val_loss: 0.4436 - val_acc: 0.9391
#
# Epoch 00041: val_acc did not improve from 0.93960
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 5e-07.
# Epoch 42/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1148 - acc: 0.9997 - val_loss: 0.4444 - val_acc: 0.9395
#
# Epoch 00042: val_acc did not improve from 0.93960
# Epoch 43/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1151 - acc: 0.9995 - val_loss: 0.4440 - val_acc: 0.9389
#
# Epoch 00043: val_acc did not improve from 0.93960
# Epoch 44/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1147 - acc: 0.9997 - val_loss: 0.4447 - val_acc: 0.9386
#
# Epoch 00044: val_acc did not improve from 0.93960
# Epoch 45/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1149 - acc: 0.9996 - val_loss: 0.4430 - val_acc: 0.9391
#
# Epoch 00045: val_acc did not improve from 0.93960
# Epoch 46/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1150 - acc: 0.9996 - val_loss: 0.4449 - val_acc: 0.9391
#
# Epoch 00046: val_acc did not improve from 0.93960
# Epoch 47/200
# 391/391 [==============================] - 176s 451ms/step - loss: 0.1149 - acc: 0.9996 - val_loss: 0.4433 - val_acc: 0.9392
#
# Epoch 00047: val_acc did not improve from 0.93960
# Epoch 48/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1149 - acc: 0.9996 - val_loss: 0.4446 - val_acc: 0.9392
#
# Epoch 00048: val_acc did not improve from 0.93960
# Epoch 49/200
# 391/391 [==============================] - 175s 449ms/step - loss: 0.1155 - acc: 0.9992 - val_loss: 0.4442 - val_acc: 0.9394
#
# Epoch 00049: val_acc did not improve from 0.93960
# Epoch 50/200
# 391/391 [==============================] - 175s 448ms/step - loss: 0.1147 - acc: 0.9997 - val_loss: 0.4451 - val_acc: 0.9388
#
# Epoch 00050: val_acc did not improve from 0.93960
# Epoch 51/200
# 391/391 [==============================] - 175s 449ms/step - loss: 0.1149 - acc: 0.9997 - val_loss: 0.4431 - val_acc: 0.9390
#
# Epoch 00051: val_acc did not improve from 0.93960
# Epoch 52/200
# 391/391 [==============================] - 175s 448ms/step - loss: 0.1150 - acc: 0.9995 - val_loss: 0.4438 - val_acc: 0.9390
#
# Epoch 00052: val_acc did not improve from 0.93960
# Epoch 53/200
# 391/391 [==============================] - 175s 449ms/step - loss: 0.1147 - acc: 0.9996 - val_loss: 0.4441 - val_acc: 0.9394
#
# Epoch 00053: val_acc did not improve from 0.93960
# Epoch 54/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1148 - acc: 0.9996 - val_loss: 0.4443 - val_acc: 0.9389
#
# Epoch 00054: val_acc did not improve from 0.93960
# Epoch 55/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1148 - acc: 0.9995 - val_loss: 0.4455 - val_acc: 0.9389
#
# Epoch 00055: val_acc did not improve from 0.93960
# Epoch 56/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1150 - acc: 0.9995 - val_loss: 0.4451 - val_acc: 0.9389
#
# Epoch 00056: val_acc did not improve from 0.93960
# Epoch 57/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1147 - acc: 0.9996 - val_loss: 0.4446 - val_acc: 0.9390
#
# Epoch 00057: val_acc did not improve from 0.93960
# Epoch 58/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1146 - acc: 0.9996 - val_loss: 0.4448 - val_acc: 0.9389
#
# Epoch 00058: val_acc did not improve from 0.93960
# Epoch 59/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1146 - acc: 0.9997 - val_loss: 0.4437 - val_acc: 0.9394
#
# Epoch 00059: val_acc did not improve from 0.93960
# Epoch 60/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1144 - acc: 0.9997 - val_loss: 0.4437 - val_acc: 0.9393
#
# Epoch 00060: val_acc did not improve from 0.93960
# Epoch 61/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1146 - acc: 0.9996 - val_loss: 0.4437 - val_acc: 0.9388
#
# Epoch 00061: val_acc did not improve from 0.93960
# Epoch 62/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1144 - acc: 0.9996 - val_loss: 0.4437 - val_acc: 0.9388
#
# Epoch 00062: val_acc did not improve from 0.93960
# Epoch 63/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1143 - acc: 0.9997 - val_loss: 0.4445 - val_acc: 0.9384
#
# Epoch 00063: val_acc did not improve from 0.93960
# Epoch 64/200
# 391/391 [==============================] - 176s 451ms/step - loss: 0.1146 - acc: 0.9995 - val_loss: 0.4447 - val_acc: 0.9391
#
# Epoch 00064: val_acc did not improve from 0.93960
# Epoch 65/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1145 - acc: 0.9995 - val_loss: 0.4458 - val_acc: 0.9391
#
# Epoch 00065: val_acc did not improve from 0.93960
# Epoch 66/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1148 - acc: 0.9995 - val_loss: 0.4449 - val_acc: 0.9390
#
# Epoch 00066: val_acc did not improve from 0.93960
# Epoch 67/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1144 - acc: 0.9996 - val_loss: 0.4456 - val_acc: 0.9387
#
# Epoch 00067: val_acc did not improve from 0.93960
# Epoch 68/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1145 - acc: 0.9995 - val_loss: 0.4456 - val_acc: 0.9389
#
# Epoch 00068: val_acc did not improve from 0.93960
# Epoch 69/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1144 - acc: 0.9995 - val_loss: 0.4462 - val_acc: 0.9389
#
# Epoch 00069: val_acc did not improve from 0.93960
# Epoch 70/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1143 - acc: 0.9997 - val_loss: 0.4445 - val_acc: 0.9393
#
# Epoch 00070: val_acc did not improve from 0.93960
# Epoch 71/200
# 391/391 [==============================] - 176s 451ms/step - loss: 0.1142 - acc: 0.9996 - val_loss: 0.4447 - val_acc: 0.9390
#
# Epoch 00071: val_acc did not improve from 0.93960
# Epoch 72/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1142 - acc: 0.9997 - val_loss: 0.4463 - val_acc: 0.9388
#
# Epoch 00072: val_acc did not improve from 0.93960
# Epoch 73/200
# 391/391 [==============================] - 175s 449ms/step - loss: 0.1141 - acc: 0.9997 - val_loss: 0.4458 - val_acc: 0.9386
#
# Epoch 00073: val_acc did not improve from 0.93960
# Epoch 74/200
# 391/391 [==============================] - 176s 451ms/step - loss: 0.1143 - acc: 0.9995 - val_loss: 0.4459 - val_acc: 0.9387
#
# Epoch 00074: val_acc did not improve from 0.93960
# Epoch 75/200
# 391/391 [==============================] - 176s 451ms/step - loss: 0.1141 - acc: 0.9997 - val_loss: 0.4455 - val_acc: 0.9386
#
# Epoch 00075: val_acc did not improve from 0.93960
# Epoch 76/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1141 - acc: 0.9996 - val_loss: 0.4452 - val_acc: 0.9393
#
# Epoch 00076: val_acc did not improve from 0.93960
# Epoch 77/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1143 - acc: 0.9997 - val_loss: 0.4455 - val_acc: 0.9392
#
# Epoch 00077: val_acc did not improve from 0.93960
# Epoch 78/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1142 - acc: 0.9996 - val_loss: 0.4454 - val_acc: 0.9392
#
# Epoch 00078: val_acc did not improve from 0.93960
# Epoch 79/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1140 - acc: 0.9995 - val_loss: 0.4451 - val_acc: 0.9391
#
# Epoch 00079: val_acc did not improve from 0.93960
# Epoch 80/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1146 - acc: 0.9993 - val_loss: 0.4443 - val_acc: 0.9388
#
# Epoch 00080: val_acc did not improve from 0.93960
# Epoch 81/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1142 - acc: 0.9996 - val_loss: 0.4440 - val_acc: 0.9383
#
# Epoch 00081: val_acc did not improve from 0.93960
# Epoch 82/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1141 - acc: 0.9995 - val_loss: 0.4435 - val_acc: 0.9394
#
# Epoch 00082: val_acc did not improve from 0.93960
# Epoch 83/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1141 - acc: 0.9996 - val_loss: 0.4437 - val_acc: 0.9388
#
# Epoch 00083: val_acc did not improve from 0.93960
# Epoch 84/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1139 - acc: 0.9997 - val_loss: 0.4445 - val_acc: 0.9392
#
# Epoch 00084: val_acc did not improve from 0.93960
# Epoch 85/200
# 391/391 [==============================] - 176s 451ms/step - loss: 0.1144 - acc: 0.9994 - val_loss: 0.4446 - val_acc: 0.9390
#
# Epoch 00085: val_acc did not improve from 0.93960
# Epoch 86/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1140 - acc: 0.9995 - val_loss: 0.4453 - val_acc: 0.9382
#
# Epoch 00086: val_acc did not improve from 0.93960
# Epoch 87/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1142 - acc: 0.9994 - val_loss: 0.4462 - val_acc: 0.9385
#
# Epoch 00087: val_acc did not improve from 0.93960
# Epoch 88/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1142 - acc: 0.9995 - val_loss: 0.4461 - val_acc: 0.9386
#
# Epoch 00088: val_acc did not improve from 0.93960
# Epoch 89/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1137 - acc: 0.9997 - val_loss: 0.4464 - val_acc: 0.9389
#
# Epoch 00089: val_acc did not improve from 0.93960
# Epoch 90/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1137 - acc: 0.9998 - val_loss: 0.4457 - val_acc: 0.9392
#
# Epoch 00090: val_acc did not improve from 0.93960
# Epoch 91/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1139 - acc: 0.9996 - val_loss: 0.4459 - val_acc: 0.9389
#
# Epoch 00091: val_acc did not improve from 0.93960
# Epoch 92/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1137 - acc: 0.9997 - val_loss: 0.4455 - val_acc: 0.9389
#
# Epoch 00092: val_acc did not improve from 0.93960
# Epoch 93/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1140 - acc: 0.9995 - val_loss: 0.4461 - val_acc: 0.9387
#
# Epoch 00093: val_acc did not improve from 0.93960
# Epoch 94/200
# 391/391 [==============================] - 175s 449ms/step - loss: 0.1140 - acc: 0.9994 - val_loss: 0.4452 - val_acc: 0.9392
#
# Epoch 00094: val_acc did not improve from 0.93960
# Epoch 95/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1138 - acc: 0.9996 - val_loss: 0.4451 - val_acc: 0.9395
#
# Epoch 00095: val_acc did not improve from 0.93960
# Epoch 96/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1137 - acc: 0.9997 - val_loss: 0.4459 - val_acc: 0.9390
#
# Epoch 00096: val_acc did not improve from 0.93960
# Epoch 97/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1136 - acc: 0.9998 - val_loss: 0.4452 - val_acc: 0.9389
#
# Epoch 00097: val_acc did not improve from 0.93960
# Epoch 98/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1135 - acc: 0.9998 - val_loss: 0.4463 - val_acc: 0.9389
#
# Epoch 00098: val_acc did not improve from 0.93960
# Epoch 99/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1138 - acc: 0.9995 - val_loss: 0.4449 - val_acc: 0.9388
#
# Epoch 00099: val_acc did not improve from 0.93960
# Epoch 100/200
# 391/391 [==============================] - 176s 451ms/step - loss: 0.1137 - acc: 0.9996 - val_loss: 0.4442 - val_acc: 0.9394
#
# Epoch 00100: val_acc did not improve from 0.93960
# Epoch 101/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1138 - acc: 0.9996 - val_loss: 0.4455 - val_acc: 0.9388
#
# Epoch 00101: val_acc did not improve from 0.93960
# Epoch 102/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1136 - acc: 0.9996 - val_loss: 0.4454 - val_acc: 0.9387
#
# Epoch 00102: val_acc did not improve from 0.93960
# Epoch 103/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1135 - acc: 0.9996 - val_loss: 0.4455 - val_acc: 0.9390
#
# Epoch 00103: val_acc did not improve from 0.93960
# Epoch 104/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1137 - acc: 0.9996 - val_loss: 0.4461 - val_acc: 0.9391
#
# Epoch 00104: val_acc did not improve from 0.93960
# Epoch 105/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1136 - acc: 0.9997 - val_loss: 0.4450 - val_acc: 0.9385
#
# Epoch 00105: val_acc did not improve from 0.93960
# Epoch 106/200
# 391/391 [==============================] - 176s 449ms/step - loss: 0.1133 - acc: 0.9998 - val_loss: 0.4457 - val_acc: 0.9392
#
# Epoch 00106: val_acc did not improve from 0.93960
# Epoch 107/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1136 - acc: 0.9996 - val_loss: 0.4455 - val_acc: 0.9391
#
# Epoch 00107: val_acc did not improve from 0.93960
# Epoch 108/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1132 - acc: 0.9998 - val_loss: 0.4467 - val_acc: 0.9394
#
# Epoch 00108: val_acc did not improve from 0.93960
# Epoch 109/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1137 - acc: 0.9995 - val_loss: 0.4469 - val_acc: 0.9395
#
# Epoch 00109: val_acc did not improve from 0.93960
# Epoch 110/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1134 - acc: 0.9996 - val_loss: 0.4467 - val_acc: 0.9392
#
# Epoch 00110: val_acc did not improve from 0.93960
# Epoch 111/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1130 - acc: 0.9997 - val_loss: 0.4473 - val_acc: 0.9388
#
# Epoch 00111: val_acc did not improve from 0.93960
# Epoch 112/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1133 - acc: 0.9997 - val_loss: 0.4467 - val_acc: 0.9394
#
# Epoch 00112: val_acc did not improve from 0.93960
# Epoch 113/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1132 - acc: 0.9997 - val_loss: 0.4457 - val_acc: 0.9390
#
# Epoch 00113: val_acc did not improve from 0.93960
# Epoch 114/200
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1134 - acc: 0.9996 - val_loss: 0.4476 - val_acc: 0.9390
#
# Epoch 00114: val_acc did not improve from 0.93960
# Epoch 115/200
#  10/391 [..............................] - ETA: 2:41 - loss: 0.1130 - acc: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-0d2eaa302df2> in <module>()
#      46               validation_data=(x_test, y_test),
#      47               steps_per_epoch=steps_per_epoch,
# ---> 48               callbacks=callbacks)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1186               logs = tmp_logs  # No error, now safe to assign to logs.
#    1187               end_step = step + data_handler.step_increment
# -> 1188               callbacks.on_train_batch_end(end_step, logs)
#    1189               if self.stop_training:
#    1190                 break
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     455     """
#     456     if self._should_call_train_batch_hooks:
# --> 457       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     458
#     459   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     315       self._call_batch_begin_hook(mode, batch, logs)
#     316     elif hook == 'end':
# --> 317       self._call_batch_end_hook(mode, batch, logs)
#     318     else:
#     319       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     335       self._batch_times.append(batch_time)
#     336
# --> 337     self._call_batch_hook_helper(hook_name, batch, logs)
#     338
#     339     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     373     for callback in self.callbacks:
#     374       hook = getattr(callback, hook_name)
# --> 375       hook(batch, logs)
#     376
#     377     if self._check_timing:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1027
#    1028   def on_train_batch_end(self, batch, logs=None):
# -> 1029     self._batch_update_progbar(batch, logs)
#    1030
#    1031   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1100       # Only block async when verbose = 1.
#    1101       logs = tf_utils.sync_to_numpy_or_python_type(logs)
# -> 1102       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1103
#    1104   def _finalize_progbar(self, logs, counter):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py in update(self, current, values, finalize)
#     965
#     966       sys.stdout.write(info)
# --> 967       sys.stdout.flush()
#     968
#     969     elif self.verbose == 2:
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in flush(self)
#     347                 self.pub_thread.schedule(evt.set)
#     348                 # and give a timeout to avoid
# --> 349                 if not evt.wait(self.flush_timeout):
#     350                     # write directly to __stderr__ instead of warning because
#     351                     # if this is happening sys.stderr may be the problem.
#
# /usr/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# /usr/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
